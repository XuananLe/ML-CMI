# %%
import numpy as np
import pandas as pd
import os
from colorama import Fore, Style

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor

from sklearn.base import clone
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import cohen_kappa_score
from scipy.optimize import minimize
from sklearn.ensemble import VotingRegressor

# from scipy.optimize import minimize
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

# %% [markdown]
# ### Mapping - Dropping features not in test sets

# %%
df = pd.read_csv("/kaggle/input/child-mind-institute-problematic-internet-use/train.csv")
df = df.dropna(subset=['sii']).reset_index() # keeping labeled values only
test = pd.read_csv("/kaggle/input/child-mind-institute-problematic-internet-use/test.csv")
season_mapping = {
    'Winter': -1,
    'Spring': -0.5,
    'Summer': 0.5,
    'Fall': 1
}
# mapping non-string values
df = df.replace(season_mapping)
test = test.replace(season_mapping)

# dropping questions not in test dataset
test_missing_columns = set(df.columns) - set(test.columns)
for col in test_missing_columns:
    if col != 'sii':  # Retain the target column for training
        df.drop(columns=col, inplace=True)
# for later use
train_ids = df['id']
test_ids = test['id']
train_labels = df['sii']
# Out:
# /tmp/ipykernel_23/117843444.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(season_mapping)
# /tmp/ipykernel_23/117843444.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test = test.replace(season_mapping)

# %%
df['sii'].value_counts()
# Out:
# sii
# 0.0    1594
# 1.0     730
# 2.0     378
# 3.0      34
# Name: count, dtype: int64

# %% [markdown]
# # K-Nearest neighboors missing data imputation

# %%
featureCols = sorted(list(set(df.columns) - set(['sii', 'id'])))
# featureCols

# %%
dropCols = []
for column in featureCols:
    if (df[column].isnull().sum() > 1300):
        dropCols.append(column)
dropCols
df = df.drop(dropCols, axis=1)

# %%
featureCols = sorted(list(set(df.columns) - set(['sii', 'id'])))
train = pd.DataFrame(df, columns=featureCols)

# %%
# !pip install /kaggle/input/cmi-wheel/cloudpickle-3.1.0-py3-none-any.whl
# !pip install /kaggle/input/cmi-wheel/geomloss-0.2.4-py3-none-any.whl
# !pip install /kaggle/input/cmi-wheel/loguru-0.6.0-py3-none-any.whl
# !pip install /kaggle/input/cmi-wheel/miracle_imputation-0.1.6-py3-none-any.whl
# !pip install /kaggle/input/cmi-wheel/pydantic-2.10.3-py3-none-any.whl
# !pip install /kaggle/input/cmi-wheel/redis_wheel-6.2.5.1-202410081222-cp311-cp311-manylinux_2_28_x86_64.whl
# Out:
# Processing /kaggle/input/cmi-wheel/cloudpickle-3.1.0-py3-none-any.whl
# cloudpickle is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing /kaggle/input/cmi-wheel/geomloss-0.2.4-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from geomloss==0.2.4) (1.26.4)
# Installing collected packages: geomloss
# Successfully installed geomloss-0.2.4
# Processing /kaggle/input/cmi-wheel/loguru-0.6.0-py3-none-any.whl
# Installing collected packages: loguru
# Successfully installed loguru-0.6.0
# Processing /kaggle/input/cmi-wheel/miracle_imputation-0.1.6-py3-none-any.whl
# Requirement already satisfied: loguru in /opt/conda/lib/python3.10/site-packages (from miracle-imputation==0.1.6) (0.6.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from miracle-imputation==0.1.6) (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from miracle-imputation==0.1.6) (2.2.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from miracle-imputation==0.1.6) (1.2.2)
# Requirement already satisfied: tensorflow>=2.0 in /opt/conda/lib/python3.10/site-packages (from miracle-imputation==0.1.6) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (1.62.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation==0.1.6) (0.37.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->miracle-imputation==0.1.6) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->miracle-imputation==0.1.6) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->miracle-imputation==0.1.6) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->miracle-imputation==0.1.6) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->miracle-imputation==0.1.6) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->miracle-imputation==0.1.6) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.0->miracle-imputation==0.1.6) (0.43.0)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.0->miracle-imputation==0.1.6) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.0->miracle-imputation==0.1.6) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.0->miracle-imputation==0.1.6) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.0->miracle-imputation==0.1.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.0->miracle-imputation==0.1.6) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.0->miracle-imputation==0.1.6) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.0->miracle-imputation==0.1.6) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.0->miracle-imputation==0.1.6) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.0->miracle-imputation==0.1.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.0->miracle-imputation==0.1.6) (3.1.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow>=2.0->miracle-imputation==0.1.6) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow>=2.0->miracle-imputation==0.1.6) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow>=2.0->miracle-imputation==0.1.6) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow>=2.0->miracle-imputation==0.1.6) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow>=2.0->miracle-imputation==0.1.6) (0.1.2)
# Installing collected packages: miracle-imputation
# Successfully installed miracle-imputation-0.1.6
# Processing /kaggle/input/cmi-wheel/pydantic-2.10.3-py3-none-any.whl
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic==2.10.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/conda/lib/python3.10/site-packages (from pydantic==2.10.3) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.10/site-packages (from pydantic==2.10.3) (4.12.2)
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.1
#     Uninstalling pydantic-2.10.1:
#       Successfully uninstalled pydantic-2.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.10.3 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.12.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed pydantic-2.10.2

# %%
# !pip install /kaggle/input/cmi-wheel-fix/pydantic-1.10.0-py3-none-any.whl 
# !pip install /kaggle/input/cmi-wheel-fix/redis-5.2.1-py3-none-any.whl
# Out:
# Processing /kaggle/input/cmi-wheel-fix/pydantic-1.10.0-py3-none-any.whl
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/conda/lib/python3.10/site-packages (from pydantic==1.10.0) (4.12.2)
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.2
#     Uninstalling pydantic-2.10.2:
#       Successfully uninstalled pydantic-2.10.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.21 requires pydantic>=2.7.0, but you have pydantic 1.10.0 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.12.0 requires pydantic>=2, but you have pydantic 1.10.0 which is incompatible.
# ydata-profiling 4.12.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed pydantic-1.10.0
# Processing /kaggle/input/cmi-wheel-fix/redis-5.2.1-py3-none-any.whl
# Requirement already satisfied: async-timeout>=4.0.3 in /opt/conda/lib/python3.10/site-packages (from redis==5.2.1) (4.0.3)
# Installing collected packages: redis
# Successfully installed redis-5.2.1

# %%
pip install /kaggle/input/jupyter-lsp-wheel/jupyter_lsp-2.2.5-py3-none-any.whl
# Out:
# Processing /kaggle/input/jupyter-lsp-wheel/jupyter_lsp-2.2.5-py3-none-any.whl
# Requirement already satisfied: jupyter-server>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-lsp==2.2.5) (2.12.5)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (4.4.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (23.1.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (3.1.4)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (6.4.5)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (5.10.4)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (7.7.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (21.3)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.20.0)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (26.0.3)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.18.1)
# Requirement already satisfied: tornado>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (6.4.1)
# Requirement already satisfied: traitlets>=5.6.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (5.14.3)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (4.12.2)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (3.11.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (4.22.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (6.0.2)
# Requirement already satisfied: referencing in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.35.1)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.8.4)
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (2.18.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.3.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (4.12.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (2.1.5)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (2.19.1)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (21.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (3.1.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.18.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (24.6.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (2.5)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (0.5.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.1.2->jupyter-lsp==2.2.5) (2.9.0.20240316)
# Installing collected packages: jupyter-lsp
#   Attempting uninstall: jupyter-lsp
#     Found existing installation: jupyter-lsp 1.5.1
#     Uninstalling jupyter-lsp-1.5.1:
#       Successfully uninstalled jupyter-lsp-1.5.1
# Successfully installed jupyter-lsp-2.2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip  install /kaggle/input/cmi-wheel-addition/jupyter-1.1.1-py2.py3-none-any.whl
# Out:
# Processing /kaggle/input/cmi-wheel-addition/jupyter-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: notebook in /opt/conda/lib/python3.10/site-packages (from jupyter==1.1.1) (6.5.7)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.10/site-packages (from jupyter==1.1.1) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.10/site-packages (from jupyter==1.1.1) (6.4.5)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.10/site-packages (from jupyter==1.1.1) (6.29.4)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (from jupyter==1.1.1) (8.1.5)
# Requirement already satisfied: jupyterlab in /opt/conda/lib/python3.10/site-packages (from jupyter==1.1.1) (4.3.1)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (8.21.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (1.6.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (5.9.3)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter==1.1.1) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jupyter==1.1.1) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jupyter==1.1.1) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from jupyter-console->jupyter==1.1.1) (3.0.47)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.10/site-packages (from jupyter-console->jupyter==1.1.1) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter==1.1.1) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter==1.1.1) (0.27.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter==1.1.1) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter==1.1.1) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter==1.1.1) (2.12.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter==1.1.1) (2.27.2)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter==1.1.1) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter==1.1.1) (70.0.0)
# Requirement already satisfied: tomli>=1.2.2 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter==1.1.1) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (0.3.0)
# Requirement already satisfied: nbformat>=4.4 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (5.10.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (0.4)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (4.12.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter==1.1.1) (2.1.5)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.1.1) (23.1.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.1.1) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.1.1) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.1.1) (0.18.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.1.1) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook->jupyter==1.1.1) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab->jupyter==1.1.1) (4.12.2)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter==1.1.1) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter==1.1.1) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter==1.1.1) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter==1.1.1) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter==1.1.1) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter==1.1.1) (0.14.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1) (0.19.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.1.1) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter==1.1.1) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.1.1) (3.11.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (0.5.3)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (7.7.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/conda/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1) (4.22.0)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.10/site-packages (from nbformat>=4.4->nbconvert->jupyter==1.1.1) (2.19.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->ipykernel->jupyter==1.1.1) (3.1.2)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.1.1) (0.2.13)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.10/site-packages (from terminado>=0.8.3->notebook->jupyter==1.1.1) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook->jupyter==1.1.1) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter==1.1.1) (2.5)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert->jupyter==1.1.1) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert->jupyter==1.1.1) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.1.1) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.1.1) (1.26.18)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.1.1) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.1.1) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.1.1) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.1.1) (0.2.2)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.1.1) (2.22)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (24.6.0)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.1.1) (2.9.0.20240316)
# Installing collected packages: jupyter
# Successfully installed jupyter-1.1.1

# %%
pip install /kaggle/input/jupyterlab-wheel/jupyterlab-4.3.3-py3-none-any.whl
# Out:
# Processing /kaggle/input/jupyterlab-wheel/jupyterlab-4.3.3-py3-none-any.whl
# Requirement already satisfied: async-lru>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (6.29.4)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (3.1.4)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (2.12.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (2.27.2)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (0.2.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (21.3)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (70.0.0)
# Requirement already satisfied: tomli>=1.2.2 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (2.0.1)
# Requirement already satisfied: tornado>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (6.4.1)
# Requirement already satisfied: traitlets in /opt/conda/lib/python3.10/site-packages (from jupyterlab==4.3.3) (5.14.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab==4.3.3) (4.12.2)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab==4.3.3) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab==4.3.3) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab==4.3.3) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab==4.3.3) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab==4.3.3) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab==4.3.3) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab==4.3.3) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab==4.3.3) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab==4.3.3) (8.21.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab==4.3.3) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab==4.3.3) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab==4.3.3) (1.6.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab==4.3.3) (5.9.3)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab==4.3.3) (26.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab==4.3.3) (2.1.5)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core->jupyterlab==4.3.3) (3.11.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (6.4.5)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (5.10.4)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (7.7.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.18.1)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/conda/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.3) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.3) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.3) (4.22.0)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.3) (2.32.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->jupyterlab==4.3.3) (3.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx>=0.25.0->jupyterlab==4.3.3) (1.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.3) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.3) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.3) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.3) (0.18.1)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab==4.3.3) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab==4.3.3) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.3.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (4.12.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.5.13)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab==4.3.3) (1.26.18)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (0.8.4)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (24.6.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (0.2.13)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab==4.3.3) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (2.5)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (0.5.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab==4.3.3) (0.2.2)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.3.3) (2.9.0.20240316)
# Installing collected packages: jupyterlab
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 4.3.1
#     Uninstalling jupyterlab-4.3.1:
#       Successfully uninstalled jupyterlab-4.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# beatrix-jupyterlab 2024.66.154055 requires jupyterlab~=3.6.0, but you have jupyterlab 4.3.3 which is incompatible.
# Successfully installed jupyterlab-4.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip  install /kaggle/input/another-hyperimputer/hyperimpute-0.1.17-py3-none-any.whl
# Out:
# Processing /kaggle/input/another-hyperimputer/hyperimpute-0.1.17-py3-none-any.whl
# Requirement already satisfied: scikit-learn>=1.0 in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (1.2.2)
# Requirement already satisfied: pandas>=1.3 in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (2.2.3)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (2.4.0)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (1.26.4)
# Requirement already satisfied: catboost>=1.0.5 in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (1.2.7)
# Requirement already satisfied: optuna>=3.1 in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (4.1.0)
# Requirement already satisfied: loguru==0.6.0 in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (0.6.0)
# Requirement already satisfied: xgboost>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (2.0.3)
# Requirement already satisfied: miracle-imputation>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (0.1.6)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (4.2.0)
# Requirement already satisfied: redis in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (5.2.1)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (3.1.0)
# Requirement already satisfied: geomloss in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (0.2.4)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (1.10.0)
# Requirement already satisfied: jupyter in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (1.1.1)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.10/site-packages (from hyperimpute==0.1.17) (6.5.7)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from catboost>=1.0.5->hyperimpute==0.1.17) (0.20.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from catboost>=1.0.5->hyperimpute==0.1.17) (3.7.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from catboost>=1.0.5->hyperimpute==0.1.17) (1.14.1)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (from catboost>=1.0.5->hyperimpute==0.1.17) (5.22.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from catboost>=1.0.5->hyperimpute==0.1.17) (1.16.0)
# Requirement already satisfied: tensorflow>=2.0 in /opt/conda/lib/python3.10/site-packages (from miracle-imputation>=0.1.3->hyperimpute==0.1.17) (2.16.1)
# Requirement already satisfied: alembic>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from optuna>=3.1->hyperimpute==0.1.17) (1.14.0)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (from optuna>=3.1->hyperimpute==0.1.17) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from optuna>=3.1->hyperimpute==0.1.17) (21.3)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /opt/conda/lib/python3.10/site-packages (from optuna>=3.1->hyperimpute==0.1.17) (2.0.30)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from optuna>=3.1->hyperimpute==0.1.17) (4.66.4)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from optuna>=3.1->hyperimpute==0.1.17) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3->hyperimpute==0.1.17) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3->hyperimpute==0.1.17) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3->hyperimpute==0.1.17) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0->hyperimpute==0.1.17) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0->hyperimpute==0.1.17) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->hyperimpute==0.1.17) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->hyperimpute==0.1.17) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->hyperimpute==0.1.17) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->hyperimpute==0.1.17) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->hyperimpute==0.1.17) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->hyperimpute==0.1.17) (2024.6.0)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.10/site-packages (from jupyter->hyperimpute==0.1.17) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.10/site-packages (from jupyter->hyperimpute==0.1.17) (6.4.5)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.10/site-packages (from jupyter->hyperimpute==0.1.17) (6.29.4)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (from jupyter->hyperimpute==0.1.17) (8.1.5)
# Requirement already satisfied: jupyterlab in /opt/conda/lib/python3.10/site-packages (from jupyter->hyperimpute==0.1.17) (4.3.3)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (6.4.1)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (26.0.3)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (23.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (5.14.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (5.7.2)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (7.4.9)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (0.2.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (5.10.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (0.18.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook->hyperimpute==0.1.17) (1.1.0)
# Requirement already satisfied: async-timeout>=4.0.3 in /opt/conda/lib/python3.10/site-packages (from redis->hyperimpute==0.1.17) (4.0.3)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna>=3.1->hyperimpute==0.1.17) (1.3.6)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client<8,>=5.3.4->notebook->hyperimpute==0.1.17) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core>=4.6.1->notebook->hyperimpute==0.1.17) (3.11.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->hyperimpute==0.1.17) (0.2.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->hyperimpute==0.1.17) (0.8.4)
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->hyperimpute==0.1.17) (2.18.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->hyperimpute==0.1.17) (0.3.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->hyperimpute==0.1.17) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->hyperimpute==0.1.17) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->hyperimpute==0.1.17) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->hyperimpute==0.1.17) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->hyperimpute==0.1.17) (4.12.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->hyperimpute==0.1.17) (0.5.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert->jupyter->hyperimpute==0.1.17) (2.1.5)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook->hyperimpute==0.1.17) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook->hyperimpute==0.1.17) (4.22.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->optuna>=3.1->hyperimpute==0.1.17) (3.1.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy>=1.4.2->optuna>=3.1->hyperimpute==0.1.17) (3.0.3)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (70.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (1.62.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (0.37.0)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.10/site-packages (from terminado>=0.8.3->notebook->hyperimpute==0.1.17) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook->hyperimpute==0.1.17) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->hyperimpute==0.1.17) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->hyperimpute==0.1.17) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->hyperimpute==0.1.17) (8.21.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->hyperimpute==0.1.17) (0.1.7)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel->jupyter->hyperimpute==0.1.17) (5.9.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jupyter->hyperimpute==0.1.17) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jupyter->hyperimpute==0.1.17) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from jupyter-console->jupyter->hyperimpute==0.1.17) (3.0.47)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter->hyperimpute==0.1.17) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter->hyperimpute==0.1.17) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter->hyperimpute==0.1.17) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter->hyperimpute==0.1.17) (2.12.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter->hyperimpute==0.1.17) (2.27.2)
# Requirement already satisfied: tomli>=1.2.2 in /opt/conda/lib/python3.10/site-packages (from jupyterlab->jupyter->hyperimpute==0.1.17) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost>=1.0.5->hyperimpute==0.1.17) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost>=1.0.5->hyperimpute==0.1.17) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost>=1.0.5->hyperimpute==0.1.17) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost>=1.0.5->hyperimpute==0.1.17) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->catboost>=1.0.5->hyperimpute==0.1.17) (10.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly->catboost>=1.0.5->hyperimpute==0.1.17) (8.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->hyperimpute==0.1.17) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (0.43.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->hyperimpute==0.1.17) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->hyperimpute==0.1.17) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->hyperimpute==0.1.17) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->hyperimpute==0.1.17) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->hyperimpute==0.1.17) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->hyperimpute==0.1.17) (0.14.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->hyperimpute==0.1.17) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->hyperimpute==0.1.17) (0.19.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->hyperimpute==0.1.17) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->hyperimpute==0.1.17) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->hyperimpute==0.1.17) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook->hyperimpute==0.1.17) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook->hyperimpute==0.1.17) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook->hyperimpute==0.1.17) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook->hyperimpute==0.1.17) (0.18.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (0.5.3)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (7.7.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/conda/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->hyperimpute==0.1.17) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->hyperimpute==0.1.17) (0.9.25)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (0.11.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->hyperimpute==0.1.17) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (1.26.18)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (3.1.3)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->hyperimpute==0.1.17) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->hyperimpute==0.1.17) (2.5)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert->jupyter->hyperimpute==0.1.17) (0.5.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->hyperimpute==0.1.17) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->hyperimpute==0.1.17) (0.8.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (0.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->hyperimpute==0.1.17) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->hyperimpute==0.1.17) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->hyperimpute==0.1.17) (0.2.2)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (24.6.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow>=2.0->miracle-imputation>=0.1.3->hyperimpute==0.1.17) (0.1.2)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->hyperimpute==0.1.17) (2.9.0.20240316)
# Installing collected packages: hyperimpute
# Successfully installed hyperimpute-0.1.17

# %%
from hyperimpute.plugins.imputers import Imputers

imputers = Imputers()

imputers.list()
# Out:
# ['miwae',
#  'miracle',
#  'sinkhorn',
#  'hyperimpute',
#  'most_frequent',
#  'softimpute',
#  'EM',
#  'median',
#  'mean',
#  'mice',
#  'sklearn_missforest',
#  'missforest',
#  'ice',
#  'nop',
#  'gain',
#  'sklearn_ice']

# %%
plugin = Imputers().get(
    "hyperimpute",
    optimizer="hyperband",
    classifier_seed=["logistic_regression"],
    regression_seed=["linear_regression"],
 
)

# method = "gain"

# plugin = Imputers().get("gian", potimizer=)
data = pd.concat([train, test], axis=0, ignore_index=True)
imputed_data = plugin.fit_transform(data[featureCols])
data = pd.DataFrame(imputed_data, columns=featureCols)
data
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# ...
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/optimize.py:43: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
#       BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0                       2.000000     2.668550    16.879200   932.498000
# 1                       2.000000     2.579490    14.037100   936.656000
# 2                       2.606120     6.088803    17.622621  1202.105684
# 3                       3.000000     3.841910    18.294300  1131.430000
# 4                       2.000000     4.330360    30.186500  1330.970000
# ...                          ...          ...          ...          ...
# 2751                    2.830187     4.485740    25.085592  1239.342400
# 2752                    2.351483     7.993372    19.499778  1190.361196
# 2753                    2.378035     4.991404    19.619916  1173.370171
# 2754                    2.000000     2.750350    17.273800  1003.070000
# 2755                    2.634329     8.515285    19.249983  1265.684071
#
#       BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# 0     1492.000000     8.255980    41.586200     13.817700     3.061430
# 1     1498.650000     6.019930    42.029100     12.825400     1.211720
# 2     2008.496903    19.656142    70.281893     14.019216     3.754320
# 3     1923.440000    15.592500    62.775700     14.074000     4.220330
# 4     1996.450000    30.212400    84.028500     16.687700    13.498800
# ...           ...          ...          ...           ...          ...
# 2751  2105.562790    20.962593    74.329481     18.466593     5.379082
# 2752  1916.021305    18.712847    69.043553     17.071568     2.747794
# 2753  1917.298477    18.073940    67.248831     15.366165     4.512180
# 2754  1504.610000    15.145600    49.103400     14.089800     3.184070
# 2755  2098.888141    21.642285    77.073048     15.129374     4.118259
#
#       BIA-BIA_Fat  ...  Physical-HeartRate  Physical-Height  Physical-Season  \
# 0        9.213770  ...           85.453346        46.000000         1.000000
# 1        3.970850  ...           70.000000        48.000000         1.000000
# 2        8.202029  ...           94.000000        56.500000         1.000000
# 3       18.824300  ...           97.000000        56.000000         0.500000
# 4       67.971500  ...           73.000000        59.500000         0.500000
# ...           ...  ...                 ...              ...              ...
# 2751    41.600407  ...           75.000000        54.000000        -0.500000
# 2752   -15.641453  ...           76.000000        44.000000        -0.500000
# 2753    18.958704  ...           81.000000        55.000000         1.000000
# 2754    11.096600  ...           91.000000        37.500000        -1.000000
# 2755    11.221403  ...           82.483602        55.751073        -0.534637
#
#       Physical-Systolic_BP  Physical-Weight  PreInt_EduHx-Season  \
# 0               110.701934        50.800000                  1.0
# 1               122.000000        46.000000                  0.5
# 2               117.000000        75.600000                  0.5
# 3               117.000000        81.600000                 -1.0
# 4               102.000000       112.200000                 -0.5
# ...                    ...              ...                  ...
# 2751             99.000000       121.600000                 -1.0
# 2752            109.000000        47.600000                 -0.5
# 2753            116.389866        85.600000                  1.0
# 2754             95.000000        60.200000                 -1.0
# 2755            116.966836        88.082344                 -1.0
#
#       PreInt_EduHx-computerinternet_hoursday  SDS-SDS_Total_Raw  \
# 0                                        3.0          40.904650
# 1                                        0.0          46.000000
# 2                                        2.0          38.000000
# 3                                        0.0          31.000000
# 4                                        0.0          40.000000
# ...                                      ...                ...
# 2751                                     2.0          35.000000
# 2752                                     0.0          37.000000
# 2753                                     1.0          40.661338
# 2754                                     3.0          39.000000
# 2755                                     2.0          40.988613
#
#       SDS-SDS_Total_T  SDS-Season
# 0           57.557086    0.885058
# 1           64.000000    1.000000
# 2           54.000000    1.000000
# 3           45.000000    0.500000
# 4           56.000000    0.500000
# ...               ...         ...
# 2751        50.000000   -0.500000
# 2752        53.000000   -0.500000
# 2753        57.336254    0.930612
# 2754        55.000000   -1.000000
# 2755        57.676472   -0.556358
#
# [2756 rows x 47 columns]

# %%
# normal
# imputer = KNNImputer(n_neighbors=5)  # k=4
# # # test 1 0.439
# # imputed_data = imputer.fit_transform(df[featureCols])
# # train = pd.DataFrame(imputed_data, columns=featureCols)
# # # train['sii'] = df['sii']
# # test_imputed = imputer.fit_transform(test[featureCols])
# # test = pd.DataFrame(test_imputed, columns=featureCols)
# # test
# # test 2
# data = pd.concat([train, test], axis=0, ignore_index=True)
# imputed_data = imputer.fit_transform(data[featureCols])
# data = pd.DataFrame(imputed_data, columns=featureCols)
# data

# %%
train.shape[0]
# Out:
# 2736

# %%
train = data.head(train.shape[0])
test = data.drop(train.index, axis=0).reset_index()

# %%
train
# Out:
#       BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0                        2.00000     2.668550    16.879200   932.498000
# 1                        2.00000     2.579490    14.037100   936.656000
# 2                        2.60612     6.088803    17.622621  1202.105684
# 3                        3.00000     3.841910    18.294300  1131.430000
# 4                        2.00000     4.330360    30.186500  1330.970000
# ...                          ...          ...          ...          ...
# 2731                     3.00000     3.203030    17.141700  1035.270000
# 2732                     1.00000     2.366800    13.645700   966.287000
# 2733                     3.00000     4.522770    16.364200  1206.880000
# 2734                     2.00000     4.413050    21.443800  1253.740000
# 2735                     4.00000     6.661680    12.237200  1414.340000
#
#       BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# 0     1492.000000     8.255980    41.586200     13.817700     3.061430
# 1     1498.650000     6.019930    42.029100     12.825400     1.211720
# 2     2008.496903    19.656142    70.281893     14.019216     3.754320
# 3     1923.440000    15.592500    62.775700     14.074000     4.220330
# 4     1996.450000    30.212400    84.028500     16.687700    13.498800
# ...           ...          ...          ...           ...          ...
# 2731  1759.960000    11.006300    52.533100     13.400400     3.741300
# 2732  1256.170000     9.988020    45.185300     13.231500     0.414263
# 2733  2051.700000    19.461100    70.811700     14.062900     2.301380
# 2734  2005.990000    20.482500    75.803300     14.804300     6.639520
# 2735  2970.120000    26.532300    92.909200     13.068400    -0.831170
#
#       BIA-BIA_Fat  ...  Physical-HeartRate  Physical-Height  Physical-Season  \
# 0        9.213770  ...           85.453346             46.0              1.0
# 1        3.970850  ...           70.000000             48.0              1.0
# 2        8.202029  ...           94.000000             56.5              1.0
# 3       18.824300  ...           97.000000             56.0              0.5
# 4       67.971500  ...           73.000000             59.5              0.5
# ...           ...  ...                 ...              ...              ...
# 2731    14.666900  ...           65.000000             52.5              1.0
# 2732     1.414700  ...           75.000000             48.5              0.5
# 2733    11.588300  ...           70.000000             59.5              1.0
# 2734    33.996700  ...           99.000000             60.0             -1.0
# 2735    -5.909170  ...           61.000000             70.7             -1.0
#
#       Physical-Systolic_BP  Physical-Weight  PreInt_EduHx-Season  \
# 0               110.701934             50.8                  1.0
# 1               122.000000             46.0                  0.5
# 2               117.000000             75.6                  0.5
# 3               117.000000             81.6                 -1.0
# 4               102.000000            112.2                 -0.5
# ...                    ...              ...                  ...
# 2731            112.000000             67.2                  1.0
# 2732            105.000000             46.6                  0.5
# 2733            104.000000             82.4                  1.0
# 2734            116.000000            109.8                  1.0
# 2735            113.000000             87.0                 -0.5
#
#       PreInt_EduHx-computerinternet_hoursday  SDS-SDS_Total_Raw  \
# 0                                        3.0           40.90465
# 1                                        0.0           46.00000
# 2                                        2.0           38.00000
# 3                                        0.0           31.00000
# 4                                        0.0           40.00000
# ...                                      ...                ...
# 2731                                     2.0           41.00000
# 2732                                     0.0           48.00000
# 2733                                     1.0           35.00000
# 2734                                     0.0           56.00000
# 2735                                     1.0           33.00000
#
#       SDS-SDS_Total_T  SDS-Season
# 0           57.557086    0.885058
# 1           64.000000    1.000000
# 2           54.000000    1.000000
# 3           45.000000    0.500000
# 4           56.000000    0.500000
# ...               ...         ...
# 2731        58.000000    1.000000
# 2732        67.000000    0.500000
# 2733        50.000000   -1.000000
# 2734        77.000000   -1.000000
# 2735        47.000000   -0.500000
#
# [2736 rows x 47 columns]

# %%
test
# Out:
#     index  BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0    2736                    2.000000     2.668550    16.879200   932.498000
# 1    2737                    2.000000     2.579490    14.037100   936.656000
# 2    2738                    2.606120     6.088803    17.622621  1202.105684
# 3    2739                    3.000000     3.841910    18.294300  1131.430000
# 4    2740                    2.419751     4.441743    18.315752  1176.293936
# 5    2741                    2.000000     4.330360    30.186500  1330.970000
# 6    2742                    2.000000     3.782710    19.662900  1135.860000
# 7    2743                    3.000000     4.057260    16.863100  1180.040000
# 8    2744                    2.524616     7.744335    18.565199  1245.760827
# 9    2745                    2.426176     4.560248    18.218754  1177.864458
# 10   2746                    2.650767     4.854311    19.070379  1190.137087
# 11   2747                    2.244819     5.384897    18.953335  1199.135836
# 12   2748                    5.000000     5.080250    21.081400  1239.460000
# 13   2749                    2.316060     7.545323    16.764252  1223.639749
# 14   2750                    2.606296     7.971297    19.062362  1252.745648
# 15   2751                    2.830187     4.485740    25.085592  1239.342400
# 16   2752                    2.351483     7.993372    19.499778  1190.361196
# 17   2753                    2.378035     4.991404    19.619916  1173.370171
# 18   2754                    2.000000     2.750350    17.273800  1003.070000
# 19   2755                    2.634329     8.515285    19.249983  1265.684071
#
#     BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  ...  \
# 0   1492.000000     8.255980    41.586200     13.817700     3.061430  ...
# 1   1498.650000     6.019930    42.029100     12.825400     1.211720  ...
# 2   2008.496903    19.656142    70.281893     14.019216     3.754320  ...
# 3   1923.440000    15.592500    62.775700     14.074000     4.220330  ...
# 4   1847.561733    20.981585    67.544003     13.974458     3.977170  ...
# 5   1996.450000    30.212400    84.028500     16.687700    13.498800  ...
# 6   1817.380000    16.327500    63.247000     14.700000     4.962910  ...
# 7   1888.060000    21.940000    67.952700     13.609200     3.253950  ...
# 8   2023.297164    22.091750    74.944295     14.246957     4.132080  ...
# 9   1846.536258    21.334367    67.710099     13.875174     3.942237  ...
# 10  1973.394107    19.549315    69.026884     14.909012     4.100083  ...
# 11  1859.739552    19.414899    69.983647     14.802717     4.131112  ...
# 12  2974.710000    19.954500    74.282300     15.659700     5.421650  ...
# 13  1885.245838    21.133326    72.581654     13.095781     3.767340  ...
# 14  2058.588333    21.700526    75.692873     14.878125     4.068870  ...
# 15  2105.562790    20.962593    74.329481     18.466593     5.379082  ...
# 16  1916.021305    18.712847    69.043553     17.071568     2.747794  ...
# 17  1917.298477    18.073940    67.248831     15.366165     4.512180  ...
# 18  1504.610000    15.145600    49.103400     14.089800     3.184070  ...
# 19  2098.888141    21.642285    77.073048     15.129374     4.118259  ...
#
#     Physical-HeartRate  Physical-Height  Physical-Season  \
# 0            85.453346        46.000000         1.000000
# 1            70.000000        48.000000         1.000000
# 2            94.000000        56.500000         1.000000
# 3            97.000000        56.000000         0.500000
# 4            78.460529        58.995661        -0.157421
# 5            73.000000        59.500000         0.500000
# 6            83.000000        55.000000         1.000000
# 7            90.000000        59.250000         1.000000
# 8            80.268234        57.664071        -0.500000
# 9            77.592425        59.457225         0.081915
# 10           81.499647        56.185548        -0.177526
# 11           83.284033        56.126312        -0.741192
# 12           79.000000        57.750000        -1.000000
# 13           71.000000        60.000000        -0.500000
# 14           81.162121        56.688705        -0.388068
# 15           75.000000        54.000000        -0.500000
# 16           76.000000        44.000000        -0.500000
# 17           81.000000        55.000000         1.000000
# 18           91.000000        37.500000        -1.000000
# 19           82.483602        55.751073        -0.534637
#
#     Physical-Systolic_BP  Physical-Weight  PreInt_EduHx-Season  \
# 0             110.701934        50.800000             1.000000
# 1             122.000000        46.000000             0.500000
# 2             117.000000        75.600000             0.500000
# 3             117.000000        81.600000            -1.000000
# 4             117.557447        87.411126            -0.303973
# 5             102.000000       112.200000            -0.500000
# 6             163.000000        84.600000             1.000000
# 7             116.000000        84.200000             1.000000
# 8             117.356804        87.821071             0.500000
# 9             117.595601        87.401960             0.272300
# 10            116.951571        87.576799            -0.500000
# 11            117.007263        87.603723             1.000000
# 12            150.000000       100.000000             1.000000
# 13            103.000000        79.600000            -0.500000
# 14            117.037737        88.018048            -0.500000
# 15             99.000000       121.600000            -1.000000
# 16            109.000000        47.600000            -0.500000
# 17            116.389866        85.600000             1.000000
# 18             95.000000        60.200000            -1.000000
# 19            116.966836        88.082344            -1.000000
#
#     PreInt_EduHx-computerinternet_hoursday  SDS-SDS_Total_Raw  \
# 0                                 3.000000          40.904650
# 1                                 0.000000          46.000000
# 2                                 2.000000          38.000000
# 3                                 0.000000          31.000000
# 4                                 1.577706          40.821754
# 5                                 0.000000          40.000000
# 6                                 3.000000          27.000000
# 7                                 2.000000          40.614353
# 8                                 2.000000          40.938433
# 9                                 1.642425          40.823658
# 10                                1.066219          40.944143
# 11                                0.000000          42.000000
# 12                                1.000000          33.000000
# 13                                1.206500          40.769706
# 14                                2.000000          40.965259
# 15                                2.000000          35.000000
# 16                                0.000000          37.000000
# 17                                1.000000          40.661338
# 18                                3.000000          39.000000
# 19                                2.000000          40.988613
#
#     SDS-SDS_Total_T  SDS-Season
# 0         57.557086    0.885058
# 1         64.000000    1.000000
# 2         54.000000    1.000000
# 3         45.000000    0.500000
# 4         57.546288   -0.325199
# 5         56.000000    0.500000
# 6         40.000000   -1.000000
# 7         57.327029    0.955986
# 8         57.644582   -0.344926
# 9         57.552609   -0.070444
# 10        57.630304   -0.200865
# 11        59.000000   -1.000000
# 12        47.000000    1.000000
# 13        57.482537   -0.459764
# 14        57.662235   -0.406717
# 15        50.000000   -0.500000
# 16        53.000000   -0.500000
# 17        57.336254    0.930612
# 18        55.000000   -1.000000
# 19        57.676472   -0.556358
#
# [20 rows x 48 columns]

# %%
train['sii'] = df['sii']
# Out:
# /tmp/ipykernel_23/2550231152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['sii'] = df['sii']

# %%
test
# Out:
#     index  BIA-BIA_Activity_Level_num  BIA-BIA_BMC  BIA-BIA_BMI  BIA-BIA_BMR  \
# 0    2736                    2.000000     2.668550    16.879200   932.498000
# 1    2737                    2.000000     2.579490    14.037100   936.656000
# 2    2738                    2.606120     6.088803    17.622621  1202.105684
# 3    2739                    3.000000     3.841910    18.294300  1131.430000
# 4    2740                    2.419751     4.441743    18.315752  1176.293936
# 5    2741                    2.000000     4.330360    30.186500  1330.970000
# 6    2742                    2.000000     3.782710    19.662900  1135.860000
# 7    2743                    3.000000     4.057260    16.863100  1180.040000
# 8    2744                    2.524616     7.744335    18.565199  1245.760827
# 9    2745                    2.426176     4.560248    18.218754  1177.864458
# 10   2746                    2.650767     4.854311    19.070379  1190.137087
# 11   2747                    2.244819     5.384897    18.953335  1199.135836
# 12   2748                    5.000000     5.080250    21.081400  1239.460000
# 13   2749                    2.316060     7.545323    16.764252  1223.639749
# 14   2750                    2.606296     7.971297    19.062362  1252.745648
# 15   2751                    2.830187     4.485740    25.085592  1239.342400
# 16   2752                    2.351483     7.993372    19.499778  1190.361196
# 17   2753                    2.378035     4.991404    19.619916  1173.370171
# 18   2754                    2.000000     2.750350    17.273800  1003.070000
# 19   2755                    2.634329     8.515285    19.249983  1265.684071
#
#     BIA-BIA_DEE  BIA-BIA_ECW  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  ...  \
# 0   1492.000000     8.255980    41.586200     13.817700     3.061430  ...
# 1   1498.650000     6.019930    42.029100     12.825400     1.211720  ...
# 2   2008.496903    19.656142    70.281893     14.019216     3.754320  ...
# 3   1923.440000    15.592500    62.775700     14.074000     4.220330  ...
# 4   1847.561733    20.981585    67.544003     13.974458     3.977170  ...
# 5   1996.450000    30.212400    84.028500     16.687700    13.498800  ...
# 6   1817.380000    16.327500    63.247000     14.700000     4.962910  ...
# 7   1888.060000    21.940000    67.952700     13.609200     3.253950  ...
# 8   2023.297164    22.091750    74.944295     14.246957     4.132080  ...
# 9   1846.536258    21.334367    67.710099     13.875174     3.942237  ...
# 10  1973.394107    19.549315    69.026884     14.909012     4.100083  ...
# 11  1859.739552    19.414899    69.983647     14.802717     4.131112  ...
# 12  2974.710000    19.954500    74.282300     15.659700     5.421650  ...
# 13  1885.245838    21.133326    72.581654     13.095781     3.767340  ...
# 14  2058.588333    21.700526    75.692873     14.878125     4.068870  ...
# 15  2105.562790    20.962593    74.329481     18.466593     5.379082  ...
# 16  1916.021305    18.712847    69.043553     17.071568     2.747794  ...
# 17  1917.298477    18.073940    67.248831     15.366165     4.512180  ...
# 18  1504.610000    15.145600    49.103400     14.089800     3.184070  ...
# 19  2098.888141    21.642285    77.073048     15.129374     4.118259  ...
#
#     Physical-HeartRate  Physical-Height  Physical-Season  \
# 0            85.453346        46.000000         1.000000
# 1            70.000000        48.000000         1.000000
# 2            94.000000        56.500000         1.000000
# 3            97.000000        56.000000         0.500000
# 4            78.460529        58.995661        -0.157421
# 5            73.000000        59.500000         0.500000
# 6            83.000000        55.000000         1.000000
# 7            90.000000        59.250000         1.000000
# 8            80.268234        57.664071        -0.500000
# 9            77.592425        59.457225         0.081915
# 10           81.499647        56.185548        -0.177526
# 11           83.284033        56.126312        -0.741192
# 12           79.000000        57.750000        -1.000000
# 13           71.000000        60.000000        -0.500000
# 14           81.162121        56.688705        -0.388068
# 15           75.000000        54.000000        -0.500000
# 16           76.000000        44.000000        -0.500000
# 17           81.000000        55.000000         1.000000
# 18           91.000000        37.500000        -1.000000
# 19           82.483602        55.751073        -0.534637
#
#     Physical-Systolic_BP  Physical-Weight  PreInt_EduHx-Season  \
# 0             110.701934        50.800000             1.000000
# 1             122.000000        46.000000             0.500000
# 2             117.000000        75.600000             0.500000
# 3             117.000000        81.600000            -1.000000
# 4             117.557447        87.411126            -0.303973
# 5             102.000000       112.200000            -0.500000
# 6             163.000000        84.600000             1.000000
# 7             116.000000        84.200000             1.000000
# 8             117.356804        87.821071             0.500000
# 9             117.595601        87.401960             0.272300
# 10            116.951571        87.576799            -0.500000
# 11            117.007263        87.603723             1.000000
# 12            150.000000       100.000000             1.000000
# 13            103.000000        79.600000            -0.500000
# 14            117.037737        88.018048            -0.500000
# 15             99.000000       121.600000            -1.000000
# 16            109.000000        47.600000            -0.500000
# 17            116.389866        85.600000             1.000000
# 18             95.000000        60.200000            -1.000000
# 19            116.966836        88.082344            -1.000000
#
#     PreInt_EduHx-computerinternet_hoursday  SDS-SDS_Total_Raw  \
# 0                                 3.000000          40.904650
# 1                                 0.000000          46.000000
# 2                                 2.000000          38.000000
# 3                                 0.000000          31.000000
# 4                                 1.577706          40.821754
# 5                                 0.000000          40.000000
# 6                                 3.000000          27.000000
# 7                                 2.000000          40.614353
# 8                                 2.000000          40.938433
# 9                                 1.642425          40.823658
# 10                                1.066219          40.944143
# 11                                0.000000          42.000000
# 12                                1.000000          33.000000
# 13                                1.206500          40.769706
# 14                                2.000000          40.965259
# 15                                2.000000          35.000000
# 16                                0.000000          37.000000
# 17                                1.000000          40.661338
# 18                                3.000000          39.000000
# 19                                2.000000          40.988613
#
#     SDS-SDS_Total_T  SDS-Season
# 0         57.557086    0.885058
# 1         64.000000    1.000000
# 2         54.000000    1.000000
# 3         45.000000    0.500000
# 4         57.546288   -0.325199
# 5         56.000000    0.500000
# 6         40.000000   -1.000000
# 7         57.327029    0.955986
# 8         57.644582   -0.344926
# 9         57.552609   -0.070444
# 10        57.630304   -0.200865
# 11        59.000000   -1.000000
# 12        47.000000    1.000000
# 13        57.482537   -0.459764
# 14        57.662235   -0.406717
# 15        50.000000   -0.500000
# 16        53.000000   -0.500000
# 17        57.336254    0.930612
# 18        55.000000   -1.000000
# 19        57.676472   -0.556358
#
# [20 rows x 48 columns]

# %% [markdown]
# # Training function using QWK metric and threshold optimization

# %%
def extract_features(df):
    # df["Feat_0"] = df["Physical-BMI"] * df["Basic_Demos-Age"]
    # df["Feat_1"] = df["PreInt_EduHx-computerinternet_hoursday"] * df["Basic_Demos-Age"]
    # df["Feat_2"] = df["Physical-BMI"] * df["PreInt_EduHx-computerinternet_hoursday"]
    # df["Feat_3"] = df["BIA-BIA_Fat"] / df["BIA-BIA_BMI"]
    # df["Feat_4"] = df["BIA-BIA_FFMI"] / df["BIA-BIA_Fat"]
    # df["Feat_5"] = df["BIA-BIA_FMI"] / df["BIA-BIA_Fat"]
    # df["Feat_6"] = df["BIA-BIA_LST"] / df["BIA-BIA_TBW"]
    # df["Feat_7"] = df["BIA-BIA_Fat"] * df["BIA-BIA_BMR"]
    # df["Feat_8"] = df["BIA-BIA_Fat"] * df["BIA-BIA_DEE"]
    # df["Feat_9"] = df["BIA-BIA_BMR"] / df["Physical-Weight"]
    # df["Feat_10"] = df["BIA-BIA_DEE"] / df["Physical-Weight"]
    # df["Feat_11"] = df["BIA-BIA_SMM"] / df["Physical-Height"]
    # df["Feat_12"] = df["BIA-BIA_SMM"] / df["BIA-BIA_FMI"]
    # df["Feat_13"] = df["BIA-BIA_TBW"] / df["Physical-Weight"]
    # df["Feat_14"] = df["BIA-BIA_ICW"] / df["BIA-BIA_TBW"]
    # df["Feat_15"] = df["Physical-BMI"] * df["Physical-HeartRate"]
    df["Feat_0"] = df["Physical-Height"] * df["PAQ_C-PAQ_C_Total"]
    df["Feat_1"] = df["FGC-FGC_TL_Zone"] * df["Physical-Height"]
    df["Feat_2"] = df["PreInt_EduHx-computerinternet_hoursday"] * df["BIA-BIA_Activity_Level_num"]
    # df["Feat_3"] = df["Fitness_Endurance-Time_Sec"] / df["PreInt_EduHx-computerinternet_hoursday"]
    df["Feat_4"] = df["CGAS-CGAS_Score"] / df["FGC-FGC_CU_Zone"]
    df["Feat_5"] = df["Basic_Demos-Age"] / df["FGC-FGC_SRR_Zone"]
    df["Feat_7"] = df["PAQ_C-PAQ_C_Total"] * df["BIA-BIA_Frame_num"]
    # df["Feat_9"] = df["FGC-FGC_GSD"] / df["SDS-SDS_Total_Raw"]
    # df["Feat_10"] = df["PAQ_A-PAQ_A_Total"] / df["PreInt_EduHx-computerinternet_hoursday"]
    df["Feat_11"] = df["BIA-BIA_LDM"] / df["PreInt_EduHx-computerinternet_hoursday"]
    df["Feat_14"] = df["BIA-BIA_BMI"] / df["SDS-SDS_Total_Raw"]
    df["Feat_15"] = df["Physical-Height"] * df["SDS-SDS_Total_T"]
    df["Feat_16"] = df["Physical-Height"] * df["Physical-Height"]
    df["Feat_17"] = df["FGC-FGC_SRL_Zone"] / df["Physical-Weight"]
    df["Feat_18"] = df["Basic_Demos-Sex"] * df["Basic_Demos-Sex"]
    # df["Feat_19"] = df["FGC-FGC_GSND_Zone"] / df["BIA-BIA_Fat"]

    return df

train = extract_features(train)
test = extract_features(test)
# Out:
# /tmp/ipykernel_23/2814183445.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_0"] = df["Physical-Height"] * df["PAQ_C-PAQ_C_Total"]
# /tmp/ipykernel_23/2814183445.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_1"] = df["FGC-FGC_TL_Zone"] * df["Physical-Height"]
# /tmp/ipykernel_23/2814183445.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_2"] = df["PreInt_EduHx-computerinternet_hoursday"] * df["BIA-BIA_Activity_Level_num"]
# /tmp/ipykernel_23/2814183445.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_4"] = df["CGAS-CGAS_Score"] / df["FGC-FGC_CU_Zone"]
# /tmp/ipykernel_23/2814183445.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_5"] = df["Basic_Demos-Age"] / df["FGC-FGC_SRR_Zone"]
# /tmp/ipykernel_23/2814183445.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_7"] = df["PAQ_C-PAQ_C_Total"] * df["BIA-BIA_Frame_num"]
# /tmp/ipykernel_23/2814183445.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_11"] = df["BIA-BIA_LDM"] / df["PreInt_EduHx-computerinternet_hoursday"]
# /tmp/ipykernel_23/2814183445.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_14"] = df["BIA-BIA_BMI"] / df["SDS-SDS_Total_Raw"]
# /tmp/ipykernel_23/2814183445.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_15"] = df["Physical-Height"] * df["SDS-SDS_Total_T"]
# /tmp/ipykernel_23/2814183445.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_16"] = df["Physical-Height"] * df["Physical-Height"]
# /tmp/ipykernel_23/2814183445.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_17"] = df["FGC-FGC_SRL_Zone"] / df["Physical-Weight"]
# /tmp/ipykernel_23/2814183445.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Feat_18"] = df["Basic_Demos-Sex"] * df["Basic_Demos-Sex"]

# %%
# qwk score
def quadratic_weighted_kappa(y_true, y_pred):
    return cohen_kappa_score(y_true, y_pred, weights='quadratic')

# threshold rounder
def threshold_Rounder(oof_non_rounded, thresholds):
    return np.where(oof_non_rounded < thresholds[0], 0,
                    np.where(oof_non_rounded < thresholds[1], 1,
                             np.where(oof_non_rounded < thresholds[2], 2, 3)))
# prediction evaluation using qwk function
def evaluate_predictions(thresholds, y_true, oof_non_rounded):
    rounded_p = threshold_Rounder(oof_non_rounded, thresholds)
    return -quadratic_weighted_kappa(y_true, rounded_p)

def TrainML(model_class, train, test_data, featureCols) -> list[float]:
    X = train[featureCols]
    y = train['sii']

    # Identify rows with NaN values in X

    # Fill NaN and infinite values in X and test_data
    X = X.fillna(0)
    X = X.replace([np.inf, -np.inf], 0)
    # test_data = test_data.fillna(0)
    test_data = test_data.replace([np.inf, -np.inf], 0)

    scaler = StandardScaler()
    scaler.fit(X)
    X = pd.DataFrame(scaler.transform(X), columns=X.columns)
    test_data = test_data[featureCols]
    test_data = pd.DataFrame(scaler.transform(test_data), columns=test_data.columns)
    # nan_mask = test_data.isnull().any(axis=1)
    # nan_indices = nan_mask[nan_mask].index
    # print(test_data)
    # print(nan_indices)
    n_splits = 5
    random_state = 42
    SKF = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    oof_non_rounded = np.zeros(len(y), dtype=float)
    oof_rounded = np.zeros(len(y), dtype=int)
    test_preds = np.zeros((len(test_data), n_splits))

    for fold, (train_idx, test_idx) in enumerate(tqdm(SKF.split(X, y), desc="Training Folds", total=n_splits)):
        X_train, X_val = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[test_idx]
        model = clone(model_class)
        model.fit(X_train, y_train)

        y_train_pred = model.predict(X_train)
        y_val_pred = model.predict(X_val)

        oof_non_rounded[test_idx] = y_val_pred
        y_val_pred_rounded = y_val_pred.round(0).astype(int)
        oof_rounded[test_idx] = y_val_pred_rounded

        test_preds[:, fold] = model.predict(test_data)

    KappaOptimizer = minimize(evaluate_predictions,
                              x0=[0.5, 1.5, 2.5], args=(y, oof_non_rounded), 
                              method='Nelder-Mead')
    assert KappaOptimizer.success, "Optimization did not converge."
    oof_tuned = threshold_Rounder(oof_non_rounded, KappaOptimizer.x)

    tpm = test_preds.mean(axis=1)
    tp_rounded = threshold_Rounder(tpm, KappaOptimizer.x)

    # Inject NaN predictions for rows with NaN in the original train
    predictions = np.array(tp_rounded.tolist())
    print(predictions)
    # for idx in nan_indices:
    #     predictions[idx] = np.nan

    return predictions.tolist()

# %% [markdown]
# # Parameters

# %%
LGBM_params = {
    'learning_rate': 0.046,
    'max_depth': 12,
    'num_leaves': 478,
    'min_data_in_leaf': 13,
    'feature_fraction': 0.893,
    'bagging_fraction': 0.784,
    'bagging_freq': 4,
    'lambda_l1': 10,  
    'lambda_l2': 0.01
}

XGB_Params = {
    'learning_rate': 0.05,
    'max_depth': 6,
    'n_estimators': 400,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'reg_alpha': 1,  
    'reg_lambda': 5,  
    'random_state': 42,
    'tree_method': 'exact'
}


CatBoost_Params = {
    'learning_rate': 0.05,
    'depth': 6,
    'iterations': 400,
    'random_seed': 42,
    'verbose': 0,
    'l2_leaf_reg': 10  
}

# %%
# !pip install --no-index --no-deps /kaggle/input/pytorchtransformer/tab_transformer_pytorch-0.3.0-py3-none-any.whl

# %%
# from pytorch_tabnet.tab_model import TabNetRegressor
# import torch
# from sklearn.base import BaseEstimator, RegressorMixin
# from sklearn.impute import SimpleImputer
# from sklearn.model_selection import train_test_split
# from pytorch_tabnet.callbacks import Callback
# import os
# import torch
# from pytorch_tabnet.callbacks import Callback

# class TabNetWrapper(BaseEstimator, RegressorMixin):
#     def __init__(self, **kwargs):
#         self.model = TabNetRegressor(**kwargs)
#         self.kwargs = kwargs
#         self.imputer = SimpleImputer(strategy='median')
#         self.best_model_path = 'best_tabnet_model.pt'
        
#     def fit(self, X, y):
#         # Handle missing values
#         X_imputed = self.imputer.fit_transform(X)
        
#         if hasattr(y, 'values'):
#             y = y.values
            
#         # Create internal validation set
#         X_train, X_valid, y_train, y_valid = train_test_split(
#             X_imputed, 
#             y, 
#             test_size=0.2,
#             random_state=42
#         )
                
#         # Train TabNet model
#         history = self.model.fit(
#             X_train=X_train,
#             y_train=y_train.reshape(-1, 1),
#             eval_set=[(X_valid, y_valid.reshape(-1, 1))],
#             eval_name=['valid'],
#             eval_metric=['mse'],
#             max_epochs=500,
#             patience=50,
#             batch_size=1024,
#             virtual_batch_size=128,
#             num_workers=0,
#             drop_last=False,
#             callbacks=[
#                 TabNetPretrainedModelCheckpoint(
#                     filepath=self.best_model_path,
#                     monitor='valid_mse',
#                     mode='min',
#                     save_best_only=True,
#                     verbose=True
#                 )
#             ]
#         )
#                 # Load the best model
#         if os.path.exists(self.best_model_path):
#             self.model.load_model(self.best_model_path)
#             os.remove(self.best_model_path)  # Remove temporary file
        
#         return self
#         def predict(self, X):
#             X_imputed = self.imputer.transform(X)
#             return self.model.predict(X_imputed).flatten()
    
#     def __deepcopy__(self, memo):
#         # Add deepcopy support for scikit-learn
#         cls = self.__class__
#         result = cls.__new__(cls)
#         memo[id(self)] = result
#         for k, v in self.__dict__.items():
#             setattr(result, k, deepcopy(v, memo))
#         return result

# TabNet_Params = {
#     'n_d': 64,              # Width of the decision prediction layer
#     'n_a': 64,              # Width of the attention embedding for each step
#     'n_steps': 5,           # Number of steps in the architecture
#     'gamma': 1.5,           # Coefficient for feature selection regularization
#     'n_independent': 2,     # Number of independent GLU layer in each GLU block
#     'n_shared': 2,          # Number of shared GLU layer in each GLU block
#     'lambda_sparse': 1e-4,  # Sparsity regularization
#     'optimizer_fn': torch.optim.Adam,
#     'optimizer_params': dict(lr=2e-2, weight_decay=1e-5),
#     'mask_type': 'entmax',
#     'scheduler_params': dict(mode="min", patience=10, min_lr=1e-5, factor=0.5),
#     'scheduler_fn': torch.optim.lr_scheduler.ReduceLROnPlateau,
#     'verbose': 1,
#     'device_name': 'cuda' if torch.cuda.is_available() else 'cpu'
# }

# class TabNetPretrainedModelCheckpoint(Callback):
#     def __init__(self, filepath, monitor='val_loss', mode='min', 
#                  save_best_only=True, verbose=1):
#         super().__init__()  # Initialize parent class
#         self.filepath = filepath
#         self.monitor = monitor
#         self.mode = mode
#         self.save_best_only = save_best_only
#         self.verbose = verbose
#         self.best = float('inf') if mode == 'min' else -float('inf')
        
#     def on_train_begin(self, logs=None):
#         self.model = self.trainer  # Use trainer itself as model
        
#     def on_epoch_end(self, epoch, logs=None):
#         logs = logs or {}
#         current = logs.get(self.monitor)
#         if current is None:
#             return

#     # Check if current metric is better than best
#     if (self.mode == 'min' and current < self.best) or \
#        (self.mode == 'max' and current > self.best):
#         if self.verbose:
#             print(f'\nEpoch {epoch}: {self.monitor} improved from {self.best:.4f} to {current:.4f}')
#         self.best = current
#         if self.save_best_only:
#             self.model.save_model(self.filepath)  # Save the entire model

# %% [markdown]
# # Model decleration

# %%
Light = LGBMRegressor(**LGBM_params, random_state=42, verbose=-1, n_estimators=300)
XGB_Model = XGBRegressor(**XGB_Params)
CatBoost_Model = CatBoostRegressor(**CatBoost_Params)

voting_model = VotingRegressor(estimators=[
    ('lightgbm', Light),
    ('xgboost', XGB_Model),
    ('catboost', CatBoost_Model)],
     weights=[0.3, 0.5, 0.2]
)

# %% [markdown]
# # XGboost model

# %%
# xgb_preds = TrainML(model_class=XGB_Model, test_data=test)
# sub = pd.DataFrame({
    
#     'id'   : test_ids,
    
#     'sii': xgb_preds
# })
# xgb_preds
# sub

# %% [markdown]
# # Light Gradient Boosting Machine model

# %%
# lgbm_preds = TrainML(model_class=Light, test_data=test)
# sub = pd.DataFrame({
    
#     'id'   : test_ids,
    
#     'sii': lgbm_preds
# })

# sub

# %% [markdown]
# # Catboost model

# %%
# cat_preds = TrainML(model_class=CatBoost_Model, test_data=test)
# sub = pd.DataFrame({
    
#     'id'   : test_ids,
    
#     'sii': cat_preds
# })

# sub

# %% [markdown]
# <h1>Handle Time Series Data</h1>

# %%
def process_file(filename, dirname):
    df = pd.read_parquet(os.path.join(dirname, filename, 'part-0.parquet'))
    df.drop('step', axis=1, inplace=True)
    return df.describe().values.reshape(-1), filename.split('=')[1]

def load_time_series(dirname) -> pd.DataFrame:
    ids = os.listdir(dirname)
    
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(lambda fname: process_file(fname, dirname), ids), total=len(ids)))
    
    stats, indexes = zip(*results)
    
    df = pd.DataFrame(stats, columns=[f"stat_{i}" for i in range(len(stats[0]))])
    df['id'] = indexes
    return df

# %%
# train_ts = load_time_series('/kaggle/input/child-mind-institute-problematic-internet-use/series_train.parquet')
# test_ts = load_time_series('/kaggle/input/child-mind-institute-problematic-internet-use/series_test.parquet')
# train_ts

# %%
# train

# %%
# train_with_ts = pd.concat([train, train_ts], axis=1, join='inner')
# test_with_ts = pd.concat([test, test_ts], axis=1).reindex(test.index)

# train_with_ts

# %% [markdown]
# # Voting regressor model - ensembler

# %%
# test_with_ts

# %%
# # featureCols
# normal_preds = TrainML(voting_model, train, test, featureCols)

# %%
# normal_preds

# %%
# def TrainML(model_class, train, test_data, featureCols) -> list[int]:
nots_featureCols = sorted(list(set(train.columns) - set(['sii', 'id'])))
# featureCols
nots_preds = TrainML(voting_model, train, test, nots_featureCols)
# Out:
# Training Folds: 100%|██████████| 5/5 [00:27<00:00,  5.44s/it]
# [2 0 0 0 1 1 0 0 2 1 1 0 1 1 2 2 0 0 0 2]

# %%
nots_preds
# Out:
# [2, 0, 0, 0, 1, 1, 0, 0, 2, 1, 1, 0, 1, 1, 2, 2, 0, 0, 0, 2]

# %%
# # def TrainML(model_class, train, test_data, featureCols) -> list[int]:
# ts_featureCols = sorted(list(set(train_with_ts.columns) - set(['sii', 'id'])))
# # featureCols
# ts_preds = TrainML(voting_model, train_with_ts, test_with_ts, ts_featureCols)

# %%
# ts_preds

# %%
# nots_preds

# %%
# vote_preds = TrainML(model_class=voting_model, test_data=test)
final_sub = pd.DataFrame({
    
    'id'   : test_ids,
    'sii': nots_preds
})


final_sub.to_csv('submission.csv', index=False)
final_sub
# Out:
#           id  sii
# 0   00008ff9    2
# 1   000fd460    0
# 2   00105258    0
# 3   00115b9f    0
# 4   0016bb22    1
# 5   001f3379    1
# 6   0038ba98    0
# 7   0068a485    0
# 8   0069fbed    2
# 9   0083e397    1
# 10  0087dd65    1
# 11  00abe655    0
# 12  00ae59c9    1
# 13  00af6387    1
# 14  00bd4359    2
# 15  00c0cd71    2
# 16  00d56d4b    0
# 17  00d9913d    0
# 18  00e6167c    0
# 19  00ebc35d    2
