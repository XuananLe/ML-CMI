# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi
os.environ["KAGGLE_USERNAME"]="xunanl"
os.environ["KAGGLE_KEY"]="0dccc777c4bdfbb77c3e2c924fe0cf25"

# %%
import kaggle
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()
api.competition_submit_cli("/home/xuananle/Documents/Learn/MachineLearning/CMI/ensemble.ipynb", "Update", "child-mind-institute-problematic-internet-use")
# Out:
# 100%|██████████| 170k/170k [00:01<00:00, 133kB/s]
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[6], line 5
#       3 api = KaggleApi()
#       4 api.authenticate()
# ----> 5 api.competition_submit_cli("/home/xuananle/Documents/Learn/MachineLearning/CMI/ensemble.ipynb", "Update", "child-mind-institute-problematic-internet-use")
#
# File ~/Documents/Learn/MachineLearning/CMI/venv/lib/python3.10/site-packages/kaggle/api/kaggle_api_extended.py:826, in KaggleApi.competition_submit_cli(self, file_name, message, competition, competition_opt, quiet)
#     824         return None
#     825     else:
# --> 826         raise e
#     827 return submit_result
#
# File ~/Documents/Learn/MachineLearning/CMI/venv/lib/python3.10/site-packages/kaggle/api/kaggle_api_extended.py:817, in KaggleApi.competition_submit_cli(self, file_name, message, competition, competition_opt, quiet)
# ...
